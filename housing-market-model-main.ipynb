# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rawData = pd.read_csv("housing.csv")

# %%
rawData
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 0             322         126         8.3252              452600
# 1            2401        1138         8.3014              358500
# 2             496         177         7.2574              352100
# 3             558         219         5.6431              341300
# 4             565         259         3.8462              342200
# ...           ...         ...            ...                 ...
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
rawData.dropna(inplace=True)

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  int64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = rawData.drop(['median_house_value'], axis=1)
Y = rawData['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
Y
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 20433, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20) # setting/reerving a batch of data for testing, in this case we are setting asside 20% as that is what is standard

# %%
train_data = X_train.join(Y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5591     -118.30     33.78                  35         2572           504.0
# 12974    -121.33     38.67                  17         2683           704.0
# 2514     -122.16     39.74                  20          707           126.0
# 9883     -121.80     36.72                  14         2493           407.0
# 13557    -117.32     34.10                  27         2053           461.0
# ...          ...       ...                 ...          ...             ...
# 14475    -117.21     32.86                  24         3596           494.0
# 13310    -117.61     34.09                  11         2000           391.0
# 10705    -117.72     33.61                  26         2033           463.0
# 14350    -117.21     32.74                  45         3025           583.0
# 8034     -118.13     33.84                  48         1895           294.0
#
#        population  households  median_income ocean_proximity  \
# 5591         1172         519         4.6207       <1H OCEAN
# 12974        1410         659         1.9620          INLAND
# 2514          337         125         3.0469          INLAND
# 9883         1296         418         5.4508       <1H OCEAN
# 13557        1737         463         3.1213          INLAND
# ...           ...         ...            ...             ...
# 14475        1573         492         6.5382      NEAR OCEAN
# 13310        1503         426         4.6167          INLAND
# 10705         618         450         2.5685       <1H OCEAN
# 14350        1980         550         2.2982      NEAR OCEAN
# 8034          881         293         6.3364       <1H OCEAN
#
#        median_house_value
# 5591               304100
# 12974              130200
# 2514                85000
# 9883               190000
# 13557               78800
# ...                   ...
# 14475              326000
# 13310              144000
# 10705               80400
# 14350               87500
# 8034               307400
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(20, 10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924946           -0.105065     0.042548
# latitude            -0.924946  1.000000            0.008142    -0.036135
# housing_median_age  -0.105065  0.008142            1.000000    -0.367693
# total_rooms          0.042548 -0.036135           -0.367693     1.000000
# total_bedrooms       0.068118 -0.068283           -0.324440     0.928667
# population           0.100492 -0.111504           -0.296754     0.852664
# households           0.055504 -0.073060           -0.306697     0.917456
# median_income       -0.019139 -0.076140           -0.123524     0.204378
# median_house_value  -0.048346 -0.141498            0.101352     0.136038
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.068118    0.100492    0.055504      -0.019139
# latitude                 -0.068283   -0.111504   -0.073060      -0.076140
# housing_median_age       -0.324440   -0.296754   -0.306697      -0.123524
# total_rooms               0.928667    0.852664    0.917456       0.204378
# total_bedrooms            1.000000    0.874591    0.979994      -0.004798
# population                0.874591    1.000000    0.904148       0.007769
# households                0.979994    0.904148    1.000000       0.016677
# median_income            -0.004798    0.007769    0.016677       1.000000
# median_house_value        0.050924   -0.024251    0.066262       0.691288
#
#                     median_house_value
# longitude                    -0.048346
# latitude                     -0.141498
# housing_median_age            0.101352
# total_rooms                   0.136038
# total_bedrooms                0.050924
# population                   -0.024251
# households                    0.066262
# median_income                 0.691288
# median_house_value            1.000000

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16346 entries, 5591 to 8034
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16346 non-null  float64
#  1   latitude            16346 non-null  float64
#  2   housing_median_age  16346 non-null  int64
#  3   total_rooms         16346 non-null  int64
#  4   total_bedrooms      16346 non-null  float64
#  5   population          16346 non-null  int64
#  6   households          16346 non-null  int64
#  7   median_income       16346 non-null  float64
#  8   ocean_proximity     16346 non-null  object
#  9   median_house_value  16346 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.9+ MB

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7240
# INLAND        5172
# NEAR OCEAN    2122
# NEAR BAY      1808
# ISLAND           4
# Name: count, dtype: int64

# %%
# Perform one-hot encoding for the "ocean_proximity" column
train_data = pd.get_dummies(train_data, columns=["ocean_proximity"], drop_first=False)

# Calculate correlation only for the numeric columns
correl = train_data.corr()
plt.figure(figsize=(20, 10))
sns.heatmap(correl, annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
print(train_data.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity_<1H OCEAN',
#        'ocean_proximity_INLAND', 'ocean_proximity_ISLAND',
#        'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(20, 10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, Y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()

reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(Y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

# Perform one-hot encoding for the "ocean_proximity" column for the test data
test_data = pd.get_dummies(test_data, columns=["ocean_proximity"], drop_first=False)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
X_test, Y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
X_test_s = scaler.transform(X_test)

# %%
print(X_train.columns)
print(X_test.columns)
# print(Y_train.columns)
# print(Y_test.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN', 'bedroom_ratio', 'household_rooms'],
#       dtype='object')
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN', 'bedroom_ratio', 'household_rooms'],
#       dtype='object')

# %%
reg.score(X_test, Y_test)
# Out:
# 0.6638463513416026

# %%
# ---Removing household_rooms & bedroom_ratio features as they do not properly aid in our predictions---

# X_train = X_train.drop(columns=["household_rooms", "bedroom_ratio"])
# X_test = X_test.drop(columns=["household_rooms", "bedroom_ratio"])
# Y_train = Y_train.drop(columns=["household_rooms", "bedroom_ratio"])
# Y_test = Y_test.drop(columns=["household_rooms", "bedroom_ratio"])

# %%
# Fit the model
reg.fit(X_train_s, Y_train)

# Score the model
linearScore = reg.score(X_test_s, Y_test)
print("Model Score:", linearScore)
# Out:
# Model Score: 0.6638137108433573

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
forestScore = forest.score(X_test, Y_test)
print("Model Score:", forestScore)
# Out:
# Model Score: 0.8180237337390536
